# %%
# %pylab inline

# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Libraries

# %%
import numpy as np
from numpy.random import randn

import pandas as pd

#time
from datetime import datetime
from datetime import timedelta

#counting
from collections import Counter

# %%
# good old matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

#high-level based on matplotlib
import seaborn as sns

#dynamic and interactive
import highcharts
from highcharts.charts import chart

# %% [markdown]
# ## Init

# %%
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})
np.random.seed(1234)

# %%
#loading highcharts javascript
highcharts.init()
# Out:
# <script src="http://code.highcharts.com/highcharts.js"></script>
# <script src="http://code.highcharts.com/highcharts-more.js"></script>

# %% [markdown]
# ## Reading data

# %% [markdown]
# ### Checkins

# %%
dfc = pd.read_csv('../../datasets/loc-gowalla_totalCheckins.txt', sep='\t', header=False)
dfc.columns = ['uid','utc','lat','lon','vid']

dfc['utc'] = dfc['utc'].astype('datetime64[ms]')

dfc.head()
# Out:
#    uid                 utc        lat        lon      vid
# 0    0 2010-10-18 22:17:43  30.269103 -97.749395   420315
# 1    0 2010-10-17 23:42:03  30.255731 -97.763386   316637
# 2    0 2010-10-17 19:26:05  30.263418 -97.757597    16516
# 3    0 2010-10-16 18:50:42  30.274292 -97.740523  5535878
# 4    0 2010-10-12 23:58:03  30.261599 -97.758581    15372

# %% [markdown]
# ### Data munging: cleanup, time parsing, etc.

# %% [markdown]
# New York, New York!
#  - bounding box: (40.4774, -74.2589), (40.9176, -73.7004)

# %%
ny = (dfc['lat']>=40.4774) & (dfc['lat']<=40.9176) & (dfc['lon']>=-74.2589) & (dfc['lon']<=-73.7004)
dfc = dfc[ny]

# %% [markdown]
# Time columns

# %%
dfc['year']     = dfc['utc'].apply(lambda x: x.date().year)
dfc['month']    = dfc['utc'].apply(lambda x: x.date().month)
dfc['day']      = dfc['utc'].apply(lambda x: x.date().day)

dfc['date']     = dfc['utc'].apply(lambda x: x.date())
dfc['time']     = dfc['utc'].apply(lambda x: x.time())

dfc['isotime']  = dfc['utc'].apply(lambda x: x.isoformat()+'Z')

dfc = dfc[dfc['date']<=datetime(2010,10,19).date()]
dfc[['uid','utc','lat','lon','vid']].head()
# Out:
#     uid                 utc        lat        lon     vid
# 9     0 2010-10-12 00:21:28  40.643885 -73.782806   23261
# 10    0 2010-10-11 20:21:20  40.741374 -73.988105   16907
# 11    0 2010-10-11 20:20:42  40.741388 -73.989455   12973
# 12    0 2010-10-11 00:06:30  40.724910 -73.994621  341255
# 13    0 2010-10-10 22:00:37  40.729768 -73.998535  260957

# %% [markdown]
# ### Venues

# %%
dfv = pd.read_csv('../../datasets/spots.txt', sep='\t', header=False)
dfv.columns = ['vid','name','loc']

coords = dfv['loc'].replace('[^0-9. -]+', '',regex=True)
coords = coords.apply(lambda x: x.split())

dfv['v_lat'] = coords.apply(lambda x: x[1])
dfv['v_lon'] = coords.apply(lambda x: x[0])

dfv = dfv.drop('loc', 1)
dfv.head()
# Out:
#        vid                       name          v_lat           v_lon
# 0  1391604      Conference House Park  40.5017589436  -74.2523431778
# 1  1391611  Almer G. Russell Pavilion  40.5022647413  -74.2542636395
# 2  3612422           Conference House  40.5000644614  -74.2490418254
# 3  3612431               Billop House  40.5000644614  -74.2490418254
# 4  1391499               Biddle House  40.5054829933  -74.2541456223

# %% [markdown]
# ### Merge venue names and checkins

# %%
df = pd.merge(dfc, dfv[['vid', 'name']], how='left', on='vid')

# %% [markdown]
# Missing venue names on the available checkins:

# %%
print "missing venue names: {}% of available checkins".format(len(df[pd.isnull(df['name'])])*100 / len(df))
# Out:
# missing venue names: 19% of available checkins

# %% [markdown]
# ## Data Exploration

# %%
d = df.groupby('date').size()

# %%
chart({
            'chart': {
                'type': 'line',
                'marginRight': 30,
                'marginBottom': 50
            },
            'title': {
                'text':'#checkins per day in New York City'
            },
            'yAxis': {
                'type': 'linear',
                'title': {'text':'#checkins'},
                
            },
            'xAxis': {
                'categories': [str(x) for x in d.index.tolist()]
            },
            'series': [{
                'name': 'date',
                'data': d.tolist()
            }]
})
# Out:
# <div id="chart_2WT3499KSA2FOA5" style="width: 100%; height: 400px; margin: 0 auto">Re-run cell if chart is not shown ...</div>
# <script>
#     do_chart_2WT3499KSA2FOA5 = function() {
#         $('#chart_2WT3499KSA2FOA5').highcharts({"series": [{"data": [6, 10, 13, 9, 13, 1, 1, 2, 1, 4, 1, 1, 3, 1, 5, 5, 2, 1, 4, 1, 1, 2, 1, 4, 1, 1, 1, 2, 1, 1, 5, 2, 2, 2, 2, 3, 1, 20, 1, 1, 1, 8, 1, 2, 3, 5, 3, 6, 1, 1, 1, 4, 1, 1, 2, 4, 4, 1, 4, 2, 9, 17, 27, 18, 22, 11, 13, 8, 7, 8, 11, 18, 11, 51, 29, 20, 23, 34, 21, 17, 20, 12, 51, 73, 59, 24, 33, 33, 59, 53, 57, 61, 79, 78, 64, 33, 56, 47, 99, 69, 85, 41, 40, 44, 80, 48, 43, 73, 47, 72, 42, 43, 42, 46, 72, 82, 112, 155, 120, 121, 78, 74, 124, 51, 88, 95, 62, 50, 125, 124, 45, 73, 83, 105, 107, 108, 128, 84, 96, 124, 159, 114, 158, 93, 168, 191, 283, 352, 234, 201, 213, 133, 152, 204, 186, 104, 93, 281, 151, 130, 267, 188, 162, 310, 212, 232, 186, 234, 174, 242, 293, 272, 185, 233, 244, 218, 258, 361, 341, 353, 242, 216, 307, 266, 335, 414, 312, 221, 219, 259, 236, 305, 324, 228, 245, 257, 333, 178, 225, 226, 234, 195, 131, 176, 308, 465, 422, 348, 250, 231, 194, 238, 241, 266, 141, 161, 208, 225, 233, 440, 447, 225, 246, 250, 242, 389, 513, 404, 234, 267, 347, 418, 434, 315, 469, 300, 331, 429, 736, 560, 656, 731, 386, 315, 469, 538, 474, 631, 689, 535, 290, 375, 434, 397, 468, 357, 358, 412, 484, 515, 537, 650, 709, 475, 397, 402, 406, 464, 451, 442, 457, 439, 394, 353, 383, 481, 401, 274, 444, 476, 422, 394, 689, 428, 262, 366, 342, 431, 405, 473, 437, 351, 300, 361, 476, 414, 487, 468, 359, 319, 283, 416, 435, 484, 494, 305, 413, 387, 394, 442, 494, 407, 360, 271, 413, 434, 413, 475, 350, 687, 370, 356, 381, 482, 543, 470, 519, 513, 406, 465, 681, 432, 429, 335, 397, 393, 437, 454, 489, 430, 357, 459, 403, 420, 398, 447, 301, 440, 545, 463, 379, 444, 447, 475, 382, 338, 391, 483, 479, 494, 461, 500, 614, 483, 379, 370, 377, 370, 476, 439, 530, 446, 503, 570, 444, 481, 501, 538, 524, 591, 599, 544, 369, 444, 426, 624, 671, 585, 462, 415, 441, 488, 433, 572, 642, 578, 368, 397, 531, 519, 661, 624, 617, 541, 626, 454, 474, 574, 684, 647, 568, 479, 487, 547, 586, 700, 573, 497, 647, 468, 462, 461, 611, 718, 541, 669, 818, 801, 700, 890, 847, 903, 744, 770, 671, 494, 855, 753, 483, 557, 647, 656, 886, 1055, 881, 757, 544, 455, 504, 678, 752, 706, 498, 478], "name": "date"}], "yAxis": {"type": "linear", "title": {"text": "#checkins"}}, "chart": {"marginBottom": 50, "type": "line", "marginRight": 30}, "xAxis": {"categories": ["2009-04-23", "2009-04-24", "2009-04-25", "2009-04-26", "2009-04-27", "2009-05-10", "2009-05-11", "2009-05-12", "2009-05-13", "2009-05-15", "2009-05-16", "2009-05-17", "2009-05-21", "2009-05-22", "2009-05-23", "2009-05-25", "2009-05-26", "2009-05-28", "2009-05-29", "2009-05-30", "2009-05-31", "2009-06-01", "2009-06-08", "2009-06-10", "2009-06-11", "2009-06-12", "2009-06-17", "2009-06-25", "2009-06-27", "2009-07-02", "2009-07-16", "2009-07-22", "2009-07-23", "2009-07-30", "2009-07-31", "2009-08-01", "2009-08-02", "2009-08-03", "2009-08-04", "2009-08-05", "2009-08-07", "2009-08-09", "2009-08-17", "2009-08-18", "2009-08-19", "2009-08-23", "2009-08-25", "2009-08-26", "2009-08-27", "2009-08-29", "2009-08-30", "2009-09-01", "2009-09-04", "2009-09-11", "2009-09-13", "2009-09-14", "2009-09-16", "2009-09-18", "2009-09-19", "2009-09-20", "2009-09-21", "2009-09-22", "2009-09-23", "2009-09-24", "2009-09-25", "2009-09-26", "2009-09-27", "2009-09-28", "2009-09-29", "2009-09-30", "2009-10-01", "2009-10-02", "2009-10-03", "2009-10-04", "2009-10-05", "2009-10-06", "2009-10-07", "2009-10-08", "2009-10-09", "2009-10-10", "2009-10-11", "2009-10-12", "2009-10-13", "2009-10-14", "2009-10-15", "2009-10-16", "2009-10-17", "2009-10-18", "2009-10-19", "2009-10-20", "2009-10-21", "2009-10-22", "2009-10-23", "2009-10-24", "2009-10-25", "2009-10-26", "2009-10-27", "2009-10-28", "2009-10-29", "2009-10-30", "2009-10-31", "2009-11-01", "2009-11-02", "2009-11-03", "2009-11-04", "2009-11-05", "2009-11-06", "2009-11-07", "2009-11-08", "2009-11-09", "2009-11-10", "2009-11-11", "2009-11-12", "2009-11-13", "2009-11-14", "2009-11-15", "2009-11-16", "2009-11-17", "2009-11-18", "2009-11-19", ...

# %% [markdown]
# ## Clustering

# %%
from sklearn.cluster import KMeans

# %%
start = datetime(2010,1,1,0,0) 
dfw = df[df['utc']>start]

# %%
cl = min(50, len(dfw)/8)
ml = KMeans(n_clusters=cl)
ml.fit(dfw[['lat', 'lon']])
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=50, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
labels = Counter(ml.labels_)
clusters = [ [ ml.cluster_centers_[x][1], ml.cluster_centers_[x][0], labels[x] ] for x in labels]
clusters
# Out:
# [[-74.028759144718549, 40.786033036363747, 480],
#  [-73.954997734611197, 40.717775764575833, 3625],
#  [-74.179811824538874, 40.691531765560633, 2210],
#  [-73.784133202672095, 40.643429900691714, 3355],
#  [-73.972033072872222, 40.757542139092955, 9832],
#  [-73.988105928795804, 40.72711000704335, 9437],
#  [-73.93296329449845, 40.823003772969727, 1351],
#  [-73.871195935667828, 40.773744853461359, 2580],
#  [-74.226380851177694, 40.883050138923743, 139],
#  [-73.9912035197802, 40.67406253981278, 2324],
#  [-74.160135369494967, 40.588651986014526, 358],
#  [-73.81869331799831, 40.824708585451788, 531],
#  [-73.983291481418945, 40.761263163035117, 15008],
#  [-74.148165246936074, 40.824503066136757, 438],
#  [-74.025411232710425, 40.623038911924667, 681],
#  [-74.034107225088249, 40.731961366395666, 2563],
#  [-73.991585926997189, 40.698408992483955, 3129],
#  [-74.050484116147018, 40.910032785624601, 504],
#  [-74.166500408258514, 40.740343192709901, 1121],
#  [-73.79884338826777, 40.710376004573966, 630],
#  [-73.974284186040762, 40.777535494340903, 7674],
#  [-73.961240487751738, 40.803748846641184, 3120],
#  [-74.215634770094823, 40.813567012252754, 618],
#  [-73.890342104741976, 40.860642209926546, 810],
#  [-73.963983208505709, 40.658446126239006, 928],
#  [-73.756202466068189, 40.76722942934893, 374],
#  [-74.101747794951024, 40.632328282308194, 537],
#  [-74.232661366608497, 40.648451459401457, 412],
#  [-74.086265705604291, 40.815963717920283, 419],
#  [-73.972299523705672, 40.580888124155464, 494],
#  [-74.003474490020423, 40.739706341952491, 6523],
#  [-73.733591896778918, 40.684803556870591, 204],
#  [-73.847263983100518, 40.71105763611115, 583],
#  [-73.955489350546529, 40.778192728903925, 4561],
#  [-73.987052876795119, 40.742675357299611, 11585],
#  [-73.924218018849842, 40.759151386632752, 1258],
#  [-74.220795321625758, 40.531905046944786, 163],
#  [-73.973280245179907, 40.681876807254355, 2329],
#  [-73.799174449840379, 40.903312513472599, 208],
#  [-73.8880891330124, 40.742633382957173, 516],
#  [-73.954939883788626, 40.858875925629675, 765],
#  [-73.837821534155921, 40.7567545926252, 869],
#  [-73.92214951056026, 40.693920764288038, 677],
#  [-74.153022707240325, 40.897507127340326, 186],
#  [-74.045457367393837, 40.692574432865811, 389],
#  [-73.99309179448619, 40.754696385898292, 8620],
#  [-74.073404777702862, 40.740824050779494, 595],
#  [-74.010669215476582, 40.709223751503963, 4318],
#  [-74.059524248493602, 40.868080531515069, 219],
#  [-74.000465811919113, 40.723997309317369, 9292]]

# %%
delta=0.15
chart({
            'chart': {
                'type': 'bubble',
                'zoomType': 'xy',
                'width':800,
                'height':800,
                'plotBackgroundImage':'https://maps.googleapis.com/maps/api/staticmap?center=40.8,-74.0&zoom=11&size=800x800&maptype=roadmap'
            },
            'plotOptions': {
              'bubble': {
                'maxSize':'5%',
                'minSize':'1%'
               }
             },
            'legend': { 
              'enabled': False
            },
            'yAxis': {
              'min':40.8-delta,
              'max':40.8+delta
            },
            'xAxis': {
              'min':-74.0-delta,
              'max':-74.0+delta
            },
            'series': [{'data': clusters, 'color':"#FF0000"}]
}, '800px', '800px')
# Out:
# <div id="chart_WN1FFRS129BYFW0" style="width: 800px; height: 800px; margin: 0 auto">Re-run cell if chart is not shown ...</div>
# <script>
#     do_chart_WN1FFRS129BYFW0 = function() {
#         $('#chart_WN1FFRS129BYFW0').highcharts({"yAxis": {"max": 40.949999999999996, "min": 40.65}, "series": [{"color": "#FF0000", "data": [[-74.028759144718549, 40.786033036363747, 480], [-73.954997734611197, 40.717775764575833, 3625], [-74.179811824538874, 40.691531765560633, 2210], [-73.784133202672095, 40.643429900691714, 3355], [-73.972033072872222, 40.757542139092955, 9832], [-73.988105928795804, 40.72711000704335, 9437], [-73.93296329449845, 40.823003772969727, 1351], [-73.871195935667828, 40.773744853461359, 2580], [-74.226380851177694, 40.883050138923743, 139], [-73.9912035197802, 40.67406253981278, 2324], [-74.160135369494967, 40.588651986014526, 358], [-73.81869331799831, 40.824708585451788, 531], [-73.983291481418945, 40.761263163035117, 15008], [-74.148165246936074, 40.824503066136757, 438], [-74.025411232710425, 40.623038911924667, 681], [-74.034107225088249, 40.731961366395666, 2563], [-73.991585926997189, 40.698408992483955, 3129], [-74.050484116147018, 40.910032785624601, 504], [-74.166500408258514, 40.740343192709901, 1121], [-73.79884338826777, 40.710376004573966, 630], [-73.974284186040762, 40.777535494340903, 7674], [-73.961240487751738, 40.803748846641184, 3120], [-74.215634770094823, 40.813567012252754, 618], [-73.890342104741976, 40.860642209926546, 810], [-73.963983208505709, 40.658446126239006, 928], [-73.756202466068189, 40.76722942934893, 374], [-74.101747794951024, 40.632328282308194, 537], [-74.232661366608497, 40.648451459401457, 412], [-74.086265705604291, 40.815963717920283, 419], [-73.972299523705672, 40.580888124155464, 494], [-74.003474490020423, 40.739706341952491, 6523], [-73.733591896778918, 40.684803556870591, 204], [-73.847263983100518, 40.71105763611115, 583], [-73.955489350546529, 40.778192728903925, 4561], [-73.987052876795119, 40.742675357299611, 11585], [-73.924218018849842, 40.759151386632752, 1258], [-74.220795321625758, 40.531905046944786, 163], [-73.973280245179907, 40.681876807254355, 2329], [-73.799174449840379, 40.903312513472599, 208], [-73.8880891330124, 40.742633382957173, 516], [-73.954939883788626, 40.858875925629675, 765], [-73.837821534155921, 40.7567545926252, 869], [-73.92214951056026, 40.693920764288038, 677], [-74.153022707240325, 40.897507127340326, 186], [-74.045457367393837, 40.692574432865811, 389], [-73.99309179448619, 40.754696385898292, 8620], [-74.073404777702862, 40.740824050779494, 595], [-74.010669215476582, 40.709223751503963, 4318], [-74.059524248493602, 40.868080531515069, 219], [-74.000465811919113, 40.723997309317369, 9292]]}], "chart": {"zoomType": "xy", "plotBackgroundImage": "https://maps.googleapis.com/maps/api/staticmap?center=40.8,-74.0&zoom=11&size=800x800&maptype=roadmap", "height": 800, "type": "bubble", "width": 800}, "plotOptions": {"bubble": {"minSize": "1%", "maxSize": "5%"}}, "xAxis": {"max": -73.85, "min": -74.15}, "legend": {"enabled": false}});
#     }
#     setTimeout("do_chart_WN1FFRS129BYFW0()", 100)
# </script>

# %% [markdown]
# ### Write data to csv file

# %% [markdown]
# ####checkins

# %%
cols = ['year','month','day','isotime','uid','lat','lon','vid']
dfc[cols].to_csv('../../datasets/checkins.csv', header=False, index=False)

# %% [markdown]
# ####venues

# %%
dfv[['vid','name','v_lat','v_lon']].to_csv('../../datasets/venues.csv', header=False, index=False)
